# %% [markdown]
# ## Projeto ETL
# ### Objetivo: Armazenar os gastos (até o momento) por deputado federal.
# 1. Obter dos dados
# 2. Efetuar os ajustes necessarios
# 3. Armazenar no banco de dados (SQLITE)

# %% [markdown]
# ### Extração

# %%
import pandas as pd
import requests

# %%
url = "https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome"
resultado = requests.get(url)

# %%
deputados = pd.DataFrame(resultado.json()['dados'])

# %%
deputados.head()
# Out:
#        id                                                uri             nome  \
# 0  204379  https://dadosabertos.camara.leg.br/api/v2/depu...   Acácio Favacho
# 1  220714  https://dadosabertos.camara.leg.br/api/v2/depu...      Adail Filho
# 2  221328  https://dadosabertos.camara.leg.br/api/v2/depu...  Adilson Barroso
# 3  204560  https://dadosabertos.camara.leg.br/api/v2/depu...     Adolfo Viana
# 4  204528  https://dadosabertos.camara.leg.br/api/v2/depu...  Adriana Ventura
#
#   siglaPartido                                         uriPartido siglaUf  \
# 0          MDB  https://dadosabertos.camara.leg.br/api/v2/part...      AP
# 1          MDB  https://dadosabertos.camara.leg.br/api/v2/part...      AM
# 2           PL  https://dadosabertos.camara.leg.br/api/v2/part...      SP
# 3         PSDB  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 4         NOVO  https://dadosabertos.camara.leg.br/api/v2/part...      SP
#
# ...

# %%
deputados.shape
# Out:
# (512, 9)

# %%
gastos = []
for id in deputados.id:
    url_despesa = f"https://dadosabertos.camara.leg.br/api/v2/deputados/{id}/despesas?ordem=ASC&ano=2023"
    resposta = requests.get(url_despesa)
    gasto = pd.DataFrame(resposta.json()['dados'])
    gasto['id'] = id
    gastos.append(gasto)

# %%
len(gastos[0])
# Out:
# 15

# %%
gastos[0]
# Out:
#      ano  mes                                        tipoDespesa codDocumento  \
# 0   2023    1               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.      7509529
# 1   2023    1                                          TELEFONIA            0
# 2   2023    1                                          TELEFONIA            0
# 3   2023    1      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES      7506338
# 4   2023    3  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...      7520851
# 5   2023    2                      COMBUSTÍVEIS E LUBRIFICANTES.      7504667
# 6   2023    2                      COMBUSTÍVEIS E LUBRIFICANTES.      7511136
# 7   2023    3                      COMBUSTÍVEIS E LUBRIFICANTES.      7520880
# 8   2023    5                      COMBUSTÍVEIS E LUBRIFICANTES.      7564652
# 9   2023    7                      COMBUSTÍVEIS E LUBRIFICANTES.      7572166
# 10  2023    8                      COMBUSTÍVEIS E LUBRIFICANTES.      7603155
# ...

# %% [markdown]
# ### Transformação

# %%
total = pd.concat(gastos)

# %%
total.head()
# Out:
#       ano  mes                                        tipoDespesa  \
# 0  2023.0  1.0               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 1  2023.0  1.0                                          TELEFONIA
# 2  2023.0  1.0                                          TELEFONIA
# 3  2023.0  1.0      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 4  2023.0  3.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#   codDocumento           tipoDocumento  codTipoDocumento        dataDocumento  \
# 0      7509529             Nota Fiscal               0.0  2023-03-14T00:00:00
# 1            0             Nota Fiscal               0.0  2023-02-15T00:00:00
# 2            0             Nota Fiscal               0.0  2023-02-14T00:00:00
# 3      7506338             Nota Fiscal               0.0  2023-02-02T00:00:00
# 4      7520851  Nota Fiscal Eletrônica               4.0  2023-03-28T00:00:00
#
#       numDocumento  valorDocumento  \
# 0              315        25000.00
# ...

# %%
# A base possui valores nulos ou ausentes?
total.isnull().sum()
# Out:
# ano                    0
# mes                    0
# tipoDespesa            0
# codDocumento           0
# tipoDocumento          0
# codTipoDocumento       0
# dataDocumento          0
# numDocumento           0
# valorDocumento         0
# urlDocumento         374
# nomeFornecedor         0
# cnpjCpfFornecedor      0
# valorLiquido           0
# valorGlosa             0
# numRessarcimento       0
# codLote                0
# parcela                0
# id                     0
# dtype: int64

# %%
del total['urlDocumento']

# %%
total.head()
# Out:
#       ano  mes                                        tipoDespesa  \
# 0  2023.0  1.0               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 1  2023.0  1.0                                          TELEFONIA
# 2  2023.0  1.0                                          TELEFONIA
# 3  2023.0  1.0      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 4  2023.0  3.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#   codDocumento           tipoDocumento  codTipoDocumento        dataDocumento  \
# 0      7509529             Nota Fiscal               0.0  2023-03-14T00:00:00
# 1            0             Nota Fiscal               0.0  2023-02-15T00:00:00
# 2            0             Nota Fiscal               0.0  2023-02-14T00:00:00
# 3      7506338             Nota Fiscal               0.0  2023-02-02T00:00:00
# 4      7520851  Nota Fiscal Eletrônica               4.0  2023-03-28T00:00:00
#
#       numDocumento  valorDocumento                             nomeFornecedor  \
# ...

# %%
total.numRessarcimento.value_counts()
# Out:
# numRessarcimento
#      6844
# 0     263
# Name: count, dtype: int64

# %%
total.shape
# Out:
# (7107, 17)

# %%
del total['numRessarcimento']

# %%
total.head()
# Out:
#       ano  mes                                        tipoDespesa  \
# 0  2023.0  1.0               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 1  2023.0  1.0                                          TELEFONIA
# 2  2023.0  1.0                                          TELEFONIA
# 3  2023.0  1.0      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 4  2023.0  3.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#   codDocumento           tipoDocumento  codTipoDocumento        dataDocumento  \
# 0      7509529             Nota Fiscal               0.0  2023-03-14T00:00:00
# 1            0             Nota Fiscal               0.0  2023-02-15T00:00:00
# 2            0             Nota Fiscal               0.0  2023-02-14T00:00:00
# 3      7506338             Nota Fiscal               0.0  2023-02-02T00:00:00
# 4      7520851  Nota Fiscal Eletrônica               4.0  2023-03-28T00:00:00
#
#       numDocumento  valorDocumento                             nomeFornecedor  \
# ...

# %%
# Verificar se há dados duplicados!

print(total.shape)
total.drop_duplicates()
print(total.shape)
# Out:
# (7107, 16)
# (7107, 16)

# %%
# Verificar se o python entendeu os valores da base como numericos

total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7107 entries, 0 to 14
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ano                7107 non-null   float64
#  1   mes                7107 non-null   float64
#  2   tipoDespesa        7107 non-null   object
#  3   codDocumento       7107 non-null   object
#  4   tipoDocumento      7107 non-null   object
#  5   codTipoDocumento   7107 non-null   float64
#  6   dataDocumento      7107 non-null   object
#  7   numDocumento       7107 non-null   object
#  8   valorDocumento     7107 non-null   float64
#  9   nomeFornecedor     7107 non-null   object
#  10  cnpjCpfFornecedor  7107 non-null   object
#  11  valorLiquido       7107 non-null   float64
#  12  valorGlosa         7107 non-null   float64
#  13  codLote            7107 non-null   float64
#  14  parcela            7107 non-null   float64
#  15  id                 7107 non-null   int64
# ...

# %%
# Agora já é possivel ter uma visão sumarizada dos meus dados
# Valor Min, Valor Max, Valor Med, Etc

total.describe()
# Out:
#           ano          mes  codTipoDocumento  valorDocumento   valorLiquido  \
# count  7107.0  7107.000000       7107.000000     7107.000000    7107.000000
# mean   2023.0     6.263262          1.142676     1892.836254    1876.459932
# std       0.0     3.430104          1.569092     4531.895776    4512.464412
# min    2023.0     1.000000          0.000000    -1875.620000   -1875.620000
# 25%    2023.0     3.000000          0.000000      200.010000     200.000000
# 50%    2023.0     6.000000          0.000000      483.120000     476.620000
# 75%    2023.0     9.000000          1.000000     1608.800000    1545.000000
# max    2023.0    12.000000          4.000000   164900.000000  164900.000000
#
#          valorGlosa       codLote      parcela             id
# count   7107.000000  7.107000e+03  7107.000000    7107.000000
# mean      14.994528  1.879299e+06     0.000704  181384.828057
# std      242.705646  3.695759e+05     0.026517   48167.564531
# ...

# %%
# Verificar divergencias nos nomes dos fornecedores

total.nomeFornecedor.value_counts().head(20)
# Out:
# nomeFornecedor
# AMORETTO CAFES EXPRESSO LTDA                                     393
# CEMIG DISTRIBUIÇÃO S.A.                                          204
# WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME                     198
# CELULAR FUNCIONAL                                                195
# 031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA         168
# BROADBRASIL LTDA                                                 132
# Companhia Energética de Pernambuco                               109
# COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA                      99
# 063 - 311 SUL - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA            87
# CEEE - Companhia Estadual de Distribuição de Energia Elétrica     77
# Copel Distribuição S.A.                                           75
# BROAD BRASIL LTDA                                                 70
# CLARO NXT TELECOMUNICAÇÕES S.A.                                   60
# ...

# %%
# Realizada limpeza, substituindo dados digitados incorretamente.
[str(fornecedor).upper().replace("S.A.","S.A").replace("S/A","S.A").replace("SA","S.A").replace("S. A.","S.A") for fornecedor in total.nomeFornecedor]
# Out:
# ['I. RODRIGUES DE ALMEIDA',
#  'CELULAR FUNCIONAL',
#  'CELULAR FUNCIONAL',
#  'E VIEGAS FERREIRA LTDA',
#  'EDVALDO FRANCISCO DE OLIVEIRA 49191160120',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  'WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME',
#  '045 - QL 02 - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
#  '050 - QI 28 - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA',
# ...

# %%
#armazenando a informação no dataframe do nome do fornecedor
total.nomeFornecedor = [str(fornecedor).upper().replace("S.A.","S.A").replace("S/A","S.A").replace("SA","S.A").replace("S. A.","S.A") for fornecedor in total.nomeFornecedor]

# %%
total.nomeFornecedor.value_counts().head(20)
# Out:
# nomeFornecedor
# AMORETTO CAFES EXPRESSO LTDA                                     393
# CEMIG DISTRIBUIÇÃO S.A                                           204
# WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME                     198
# CELULAR FUNCIONAL                                                195
# 031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA         168
# BROADBRASIL LTDA                                                 132
# CLARO NXT TELECOMUNICAÇÕES S.A                                   128
# COMPANHIA ENERGÉTICA DE PERNAMBUCO                               109
# COMPANHIA DE ELETRICIDADE DO ESTADO DA BAHIA                      99
# 063 - 311 SUL - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA            87
# CEEE - COMPANHIA ESTADUAL DE DISTRIBUIÇÃO DE ENERGIA ELÉTRICA     77
# COPEL DISTRIBUIÇÃO S.A                                            75
# BROAD BRASIL LTDA                                                 70
# ...

# %% [markdown]
# ### Load (Carga)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///dados_abertos.bd')

# %%
deputados.to_sql('deputados', engine)
# Out:
# 512

# %%
total.to_sql('despesas_total', engine)
# Out:
# 7107

# %% [markdown]
# ### Análise

# %%
total = pd.read_sql("select * from despesas_total;", engine)
total.head()
# Out:
#    index     ano  mes                                        tipoDespesa  \
# 0      0  2023.0  1.0               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 1      1  2023.0  1.0                                          TELEFONIA
# 2      2  2023.0  1.0                                          TELEFONIA
# 3      3  2023.0  1.0      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 4      4  2023.0  3.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#   codDocumento           tipoDocumento  codTipoDocumento        dataDocumento  \
# 0      7509529             Nota Fiscal               0.0  2023-03-14T00:00:00
# 1            0             Nota Fiscal               0.0  2023-02-15T00:00:00
# 2            0             Nota Fiscal               0.0  2023-02-14T00:00:00
# 3      7506338             Nota Fiscal               0.0  2023-02-02T00:00:00
# 4      7520851  Nota Fiscal Eletrônica               4.0  2023-03-28T00:00:00
#
# ...

# %%
deputados = pd.read_sql("select *from deputados", engine)
deputados.head()
# Out:
#    index      id                                                uri  \
# 0      0  204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1      1  220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2      2  221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3      3  204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4      4  204528  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#               nome siglaPartido  \
# 0   Acácio Favacho          MDB
# 1      Adail Filho          MDB
# 2  Adilson Barroso           PL
# 3     Adolfo Viana         PSDB
# 4  Adriana Ventura         NOVO
#
#                                           uriPartido siglaUf  idLegislatura  \
# 0  https://dadosabertos.camara.leg.br/api/v2/part...      AP             57
# 1  https://dadosabertos.camara.leg.br/api/v2/part...      AM             57
# 2  https://dadosabertos.camara.leg.br/api/v2/part...      SP             57
# ...

# %%
total.head()
# Out:
#    index_x     ano  mes                                        tipoDespesa  \
# 0        0  2023.0  1.0               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 1        1  2023.0  1.0                                          TELEFONIA
# 2        2  2023.0  1.0                                          TELEFONIA
# 3        3  2023.0  1.0      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 4        4  2023.0  3.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#   codDocumento           tipoDocumento  codTipoDocumento        dataDocumento  \
# 0      7509529             Nota Fiscal               0.0  2023-03-14T00:00:00
# 1            0             Nota Fiscal               0.0  2023-02-15T00:00:00
# 2            0             Nota Fiscal               0.0  2023-02-14T00:00:00
# 3      7506338             Nota Fiscal               0.0  2023-02-02T00:00:00
# 4      7520851  Nota Fiscal Eletrônica               4.0  2023-03-28T00:00:00
#
# ...

# %%
total = total.rename(columns={'nome_y':'nome_deputado'})
gastos_deputados = total.groupby(['nome_deputado']).sum()[['valorDocumento','valorLiquido']]

# %%
#Ordenando os gastos pelo valor do documento
gastos_deputados = gastos_deputados.sort_values('valorDocumento', ascending=False)

# %%
#Top 10 Deputados que Mais gastaram
gastos_deputados.head(10)
# Out:
#                        valorDocumento  valorLiquido
# nome_deputado
# Eunício Oliveira            426525.79     426525.79
# Glaustin da Fokus           332829.10     332829.10
# Gustinho Ribeiro            261700.00     261700.00
# Hercílio Coelho Diniz       260814.47     260814.47
# Delegado Éder Mauro         217381.15     217381.15
# Altineu Côrtes              192900.00     192900.00
# Renilce Nicodemos           186563.08     185992.00
# Pedro Paulo                 184059.81     183071.21
# Professor Alcides           170796.06     168755.86
# Magda Mofatto               163530.77     163410.59

# %%
#Top 10 Deputados que Menos gastaram
gastos_deputados.tail(10)
# Out:
#                        valorDocumento  valorLiquido
# nome_deputado
# Guilherme Derrite             1638.00       1638.00
# Romero Rodrigues              1619.61       1513.72
# Flávio Nogueira               1542.28       1526.48
# Sargento Fahur                1480.01       1472.45
# Paulo Litro                    970.06        970.06
# Ricardo Barros                 830.24        830.24
# Hildo Rocha                    376.45        376.45
# Professora Marcivania          117.90        117.90
# André Abdon                     44.09         44.09
# Aline Gurgel                 -3928.04      -3928.04

# %%
#Verificando alguns Gráficos!
# %matplotlib inline

# %%
total.nomeFornecedor.value_counts()[:10].plot(kind="bar")
# Out:
# <Axes: xlabel='nomeFornecedor'>
